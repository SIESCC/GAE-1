# %% [markdown]
# <a href="https://colab.research.google.com/github/SIESCC/GAE-1/blob/main/Chotarajan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Practical 1
# ##Write a python program to implement Link Analysis.

# %%
# !pip install requests beautifulsoup4
#Link analysis
from urllib.parse import urlparse
url="https://www.youtube.com/watch?v=RgOEKdA2mlw"
parsed_url = urlparse(url)
print("Parsed URL Components:")
print("Scheme: ",parsed_url.scheme)
print("Netlocation: ",parsed_url.netloc)
print("Path: ",parsed_url.path)
print("Query: ",parsed_url.query)
# Out:
# ...
# Parsed URL Components:
# Scheme:  https
# Netlocation:  www.youtube.com
# Path:  /watch
# Query:  v=RgOEKdA2mlw

# %% [markdown]
# #Practical 2
# ##Write a python program to make a web graph

# %%
import networkx as nx
import matplotlib.pyplot as plt
# create a directed graph
G = nx.DiGraph()
# Add edges representing links between web pages
edges = [
    ("Home","About"),
    ("Home", "Services"),
    ("About","Team"),
    ("Services","Contact"),
    ("Contact","Home"),
    ("Services","About")
]
G.add_edges_from(edges)
#Draw the graph
pos = nx.spring_layout(G) #positions from all nodes
nx.draw(G,pos,with_labels = True, arrows=True)
plt.title("Website Link Graph")
plt.show()

# %% [markdown]
# #Practical 3
# ##Write a python program to perform simple crawling from Wikipedia using keywords

# %%
# Crawling through Wikipedia
import requests
from bs4 import BeautifulSoup
def simple_crawler(keyword):
    url = f"https://en.wikipedia.org/wiki/Special:Search?search={keyword}"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    for link in soup.find_all('a',href=True):
        if link['href'].startswith('/wiki/') and ':' not in link['href']:
            print(f"https://en.wikipedia.org{link['href']}")
keyword = input("Enter a keyword to search: ")
simple_crawler(keyword)
# Out:
# Enter a keyword to search: code
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Code
# https://en.wikipedia.org/wiki/Code
# https://en.wikipedia.org/wiki/Code
# https://en.wikipedia.org/wiki/Code_(disambiguation)
# https://en.wikipedia.org/wiki/Encoding_(disambiguation)
# https://en.wikipedia.org/wiki/Code_01_Bad_Girl
# https://en.wikipedia.org/wiki/Code_02_Pretty_Pretty
# https://en.wikipedia.org/wiki/Communication
# https://en.wikipedia.org/wiki/Data_processing
# https://en.wikipedia.org/wiki/Information
# https://en.wikipedia.org/wiki/Letter_(alphabet)
# https://en.wikipedia.org/wiki/Word
# https://en.wikipedia.org/wiki/Gesture
# https://en.wikipedia.org/wiki/Data_compression
# https://en.wikipedia.org/wiki/Secrecy
# https://en.wikipedia.org/wiki/Communication_channel
# https://en.wikipedia.org/wiki/Storage_medium
# https://en.wikipedia.org/wiki/Language
# https://en.wikipedia.org/wiki/Speech
# ...

# %% [markdown]
# #Practical 4
# ##Write a python program to fetch page content

# %%
# Fetch page
import requests
def fetch_page(url):
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status() # Raise an HTTPError for bad responses
        return response.text
    except requests.exceptions.HTTPError as e:
        print(f"HTTP error occurred: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")
url=" https://en.wikipedia.org/wiki/Monkey_D._Luffy"
# Replace with the target URL
page_content = fetch_page(url)
if page_content:
    print(page_content)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>Monkey D. Luffy - Wikipedia</title>
# ...

# %% [markdown]
# #Practical 5
# ##Write a python program for Hits Algorithm

# %%
# HITS
import networkx as nx
G = nx.DiGraph()
# G.add_edges_from([(1,2), (1,3), (2,4), (3,4), (4,5)])
G.add_edges_from([('p','q'), ('p','s'), ('p','r'), ('q','r'), ('r','p'), ('s','s')])
authority_score, hub_score = nx.hits(G)
print(f"Authority Scores: {authority_score}")
print(f"Hub Scores: {hub_score}")
# Out:
# Authority Scores: {'p': 0.5773502691896258, 'q': 0.21132486540518716, 's': 0.21132486540518716, 'r': 0.0}
# Hub Scores: {'p': 0.0, 'q': 0.2679491924311227, 's': 0.36602540378443865, 'r': 0.36602540378443865}

# %% [markdown]
# #Practical 6
# ##Write a python program for Page Rank

# %%
# Page rank using NetworkX
import networkx as nx
import matplotlib.pyplot as plt
G = nx.DiGraph()
G.add_edges_from([
    ('A','B'),('A','C'),('B','A'),('B','D'),('B','E'),('B','F'),
    ('C','A'),('C','F')])
pr = nx.pagerank(G,alpha=0.85)
for node, rank in pr.items():
    print(f"Node -> {node}:{rank}")
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos,node_size=[pr[node]*1000 for node in G.nodes()])
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos)
plt.show()
# Out:
# Node -> A:0.1999690383608587
# Node -> B:0.17401971598239518
# Node -> C:0.17401971598239518
# Node -> D:0.1260112456567459
# Node -> E:0.1260112456567459
# Node -> F:0.1999690383608587

# %% [markdown]
# #Practical 7
# ##Write a python program to summarize Text

# %%
# !pip install sumy

import nltk
nltk.download('punkt')

from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer
from sumy.summarizers.luhn import LuhnSummarizer

def summarize_text(text, num_sentences=2):
    parser = PlaintextParser.from_string(text, Tokenizer("english"))

    lex_summarizer = LexRankSummarizer()
    lex_summary = lex_summarizer(parser.document, num_sentences)

    summarized_text = " ".join(str(sentence) for sentence in lex_summary)

    if not summarized_text or summarized_text.strip() == text.strip():
        luhn_summarizer = LuhnSummarizer()
        luhn_summary = luhn_summarizer(parser.document, num_sentences)
        summarized_text = " ".join(str(sentence) for sentence in luhn_summary)

    return summarized_text.strip()

text = """
Artificial intelligence is revolutionizing the world by enabling machines to perform tasks that typically require human intelligence. From virtual assistants and recommendation systems to autonomous vehicles and medical diagnostics, AI is reshaping industries and improving efficiency. As technology continues to evolve, the ethical implications and societal impact of AI are becoming increasingly important to consider.
"""

summary = summarize_text(text)
print("Summary:", summary)
# Out:
# ...
# Summary: Artificial intelligence is revolutionizing the world by enabling machines to perform tasks that typically require human intelligence. From virtual assistants and recommendation systems to autonomous vehicles and medical diagnostics, AI is reshaping industries and improving efficiency.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #Practical 8
# ##Write a python program to implement a Recommender System.

# %%
# !pip install numpy==1.23.5

# !pip install scikit-surprise

import pandas as pd
from surprise import SVD, Dataset, Reader, accuracy
from surprise.model_selection import train_test_split


data = {
    'user_id': [1,1,1,2,2,3,3,3,4,4],
    'item_id': ['A','B','C','A','C','A','B','D','B','C'],
    'rating' : [5,3,4,4,5,5,1,2,4,1]
}

df = pd.DataFrame(data)
reader = Reader(rating_scale=(1,5))
dataset = Dataset.load_from_df(df[['user_id','item_id','rating']],reader)

trainset, testset = train_test_split(dataset, test_size=0.2)
model = SVD()
model.fit(trainset)

predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
print(f"RMSE: {rmse:.4f}")

pred = model.predict(3,'B')
print(f"Prediction for user 3, item B: {pred.est:.2f}")
# Out:
# ...
# RMSE: 1.3490
# RMSE: 1.3490
# Prediction for user 3, item B: 2.63
